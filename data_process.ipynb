# %% [markdown]
# # Convert Label format to YOLO

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
from PIL import Image
from collections import Counter
import random

# %%
# # Get list of images
# images = [f for f in os.listdir('Dataset/Train/images') if f.endswith('.jpg')]
# # train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

# # Create new train/val directories
# os.makedirs('yolo_dataset/train/images', exist_ok=True)
# os.makedirs('yolo_dataset/train/labels', exist_ok=True)
# os.makedirs('yolo_dataset/val/images', exist_ok=True)
# os.makedirs('yolo_dataset/val/labels', exist_ok=True)

# # Copy files
# for img in images:
#     shutil.copy(f'Dataset/Train/images/{img}', f'yolo_dataset/train/images/{img}')
#     shutil.copy(f'Dataset/Train/labels/{img.replace(".jpg", ".txt")}', f'yolo_dataset/train/labels/{img.replace(".jpg", ".txt")}')
# # for img in val_imgs:
# #     shutil.copy(f'Dataset/Train/images/{img}', f'split_dataset/val/images/{img}')
# #     shutil.copy(f'Dataset/Train/labels/{img.replace(".jpg", ".txt")}', f'split_dataset/val/labels/{img.replace(".jpg", ".txt")}')

# %%
def convert_to_yolo(input_dir, output_dir, images_dir):
    os.makedirs(output_dir, exist_ok=True)
    for label_file in os.listdir(input_dir):
        if not label_file.endswith('.txt'):
            continue
        # Get corresponding image to extract dimensions
        img_file = label_file.replace('.txt', '.jpg')
        img_path = os.path.join(images_dir, img_file)
        try:
            img = Image.open(img_path)
            img_width, img_height = img.size
        except FileNotFoundError:
            print(f"Image {img_file} not found, skipping.")
            continue
        
        # Read label file
        with open(os.path.join(input_dir, label_file), 'r') as f:
            lines = f.readlines()
        
        # Convert to YOLO format
        yolo_lines = []
        for line in lines:
            parts = line.strip().split()
            if len(parts) != 5:
                print(f"Invalid format in {label_file}: {line}")
                continue
            class_id, x_min, y_min, x_max, y_max = map(float, parts)
            # Convert to YOLO format
            x_center = (x_min + x_max) / 2 / img_width
            y_center = (y_min + y_max) / 2 / img_height
            width = (x_max - x_min) / img_width
            height = (y_max - y_min) / img_height
            yolo_lines.append(f"{int(class_id)} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")
        
        # Save converted label
        with open(os.path.join(output_dir, label_file), 'w') as f:
            f.write('\n'.join(yolo_lines))

# Convert train and validation labels
convert_to_yolo('Dataset/Train/labels', 'yolo_dataset/train/labels', 'Dataset/Train/images')
# convert_to_yolo('split_dataset/val/labels', 'yolo_dataset/val/labels', 'split_dataset/val/images')

# %%
train_class_apple = []
train_class_banana = []
train_class_grapes = []
train_class_orange = []
train_class_pineapple = []
train_class_watermelon = []
train_mix_class = []

labels_dir = 'yolo_dataset/train/labels'
images_dir = 'yolo_dataset/train/images'

new_labels_dir = 'yolo_dataset/new_train/labels'
new_images_dir = 'yolo_dataset/new_train/images'


for label_file in os.listdir(labels_dir):
    class_ids = set()  # Tập hợp các class trong ảnh này
    with open(os.path.join(labels_dir, label_file)) as f:
        for line in f:
            class_id = line.split()[0]
            class_ids.add(class_id)

    if class_ids == {'0'}:
        train_class_apple.append(label_file)
    elif class_ids == {'1'}:
        train_class_banana.append(label_file)
    elif class_ids == {'2'}:
        train_class_grapes.append(label_file)
    elif class_ids == {'3'}:
        train_class_orange.append(label_file)
    elif class_ids == {'4'}:
        train_class_pineapple.append(label_file)
    elif class_ids == {'5'}:
        train_class_watermelon.append(label_file)
    else:
        train_mix_class.append(label_file)

# %%
print(f"Số lượng ảnh trước khi lọc số lượng class của Apple: {len(train_class_apple)}")
print(f"Số lượng ảnh trước khi lọc số lượng class của Banana: {len(train_class_banana)}")
print(f"Số lượng ảnh trước khi lọc số lượng class của Grapes: {len(train_class_grapes)}")
print(f"Số lượng ảnh trước khi lọc số lượng class của Orange: {len(train_class_orange)}")
print(f"Số lượng ảnh trước khi lọc số lượng class của Pineapple: {len(train_class_pineapple)}")
print(f"Số lượng ảnh trước khi lọc số lượng class của Watermelon: {len(train_class_watermelon)}")
print(f"Số lượng ảnh mix trước khi lọc số lượng: {len(train_mix_class)}")
# Out:
# Số lượng ảnh trước khi lọc số lượng class của Apple: 1521
# Số lượng ảnh trước khi lọc số lượng class của Banana: 1188
# Số lượng ảnh trước khi lọc số lượng class của Grapes: 1540
# Số lượng ảnh trước khi lọc số lượng class của Orange: 1783
# Số lượng ảnh trước khi lọc số lượng class của Pineapple: 582
# Số lượng ảnh trước khi lọc số lượng class của Watermelon: 750
# Số lượng ảnh mix trước khi lọc số lượng: 267

# %%
# Đặt seed để kết quả random có thể lặp lại nếu cần
random.seed(42)

train_class_orange = random.sample(train_class_orange, min(800, len(train_class_orange))) # Orange

train_class_banana_test = train_class_banana * 2
train_class_watermelon_test = train_class_watermelon * 2
train_class_pineapple_test = train_class_pineapple * 2
train_mix_class_test = train_mix_class * 2

# %%
print(f"Số lượng ảnh sau khi lọc số lượng class của Apple: {len(train_class_apple)}")
print(f"Số lượng ảnh sau khi lọc số lượng class của Banana: {len(train_class_banana_test)}")
print(f"Số lượng ảnh sau khi lọc số lượng class của Grapes: {len(train_class_grapes)}")
print(f"Số lượng ảnh sau khi lọc số lượng class của Orange: {len(train_class_orange)}")
print(f"Số lượng ảnh sau khi lọc số lượng class của Pineapple: {len(train_class_pineapple_test)}")
print(f"Số lượng ảnh sau khi lọc số lượng class của Watermelon: {len(train_class_watermelon_test)}")
print(f"Số lượng ảnh mix sau khi lọc số lượng: {len(train_mix_class_test)}")
# Out:
# Số lượng ảnh sau khi lọc số lượng class của Apple: 1521
# Số lượng ảnh sau khi lọc số lượng class của Banana: 2376
# Số lượng ảnh sau khi lọc số lượng class của Grapes: 1540
# Số lượng ảnh sau khi lọc số lượng class của Orange: 800
# Số lượng ảnh sau khi lọc số lượng class của Pineapple: 1164
# Số lượng ảnh sau khi lọc số lượng class của Watermelon: 1500
# Số lượng ảnh mix sau khi lọc số lượng: 534

# %%
all_train_files = (
    train_class_apple +
    train_class_grapes +
    train_class_orange 
)

# %%
# all_train_files = (
#     train_class_apple +
#     train_class_banana_test +
#     train_class_grapes +
#     train_class_orange_test +
#     train_class_pineapple_test +
#     train_class_watermelon_test +
#     train_mix_class_test
# )

# %%
len(all_train_files)
# Out:
# 3861

# %%
train_class_counts = Counter()
for label_file in all_train_files:
    with open(os.path.join(labels_dir, label_file)) as f:
        for line in f:
            class_id = line.split()[0]
            train_class_counts[class_id] += 1
print(train_class_counts)
# Out:
# Counter({'2': 6373, '3': 6106, '0': 5827})

# %%
import shutil

def copy_labels_images(train_list, labels_dir, images_dir, dest_labels_dir, dest_images_dir):
    os.makedirs(dest_labels_dir, exist_ok=True)
    os.makedirs(dest_images_dir, exist_ok=True)
    for label_file in train_list:
        # Copy labels
        label_src_path = os.path.join(labels_dir, label_file)
        label_dest_path = os.path.join(dest_labels_dir, label_file)
        shutil.copy(label_src_path, label_dest_path)
        
        # Copy images
        image_file = label_file.replace('.txt', '.jpg')
        image_src_path = os.path.join(images_dir, image_file)
        image_dest_path = os.path.join(dest_images_dir, image_file)
        if os.path.exists(image_src_path):
            shutil.copy(image_src_path, image_dest_path)
        else:
            print(f"WARNING: File ảnh không tồn tại: {image_src_path}")
            
            
copy_labels_images(all_train_files, labels_dir, images_dir, new_labels_dir, new_images_dir)

# %%
os.makedirs('temp_b', exist_ok=True)
os.makedirs('temp_p', exist_ok=True)
os.makedirs('temp_w', exist_ok=True)
os.makedirs('temp_mix', exist_ok=True)

# %%
import shutil

def duplicate_rare_classes(train_list, labels_dir, images_dir, dest_labels_dir, dest_images_dir, duplicate_factor=2):
    os.makedirs(dest_labels_dir, exist_ok=True)
    os.makedirs(dest_images_dir, exist_ok=True)
    train_files = []
    
    for label_file in train_list:
        if not label_file.endswith('.txt'):
            continue
        label_src_path = os.path.join(labels_dir, label_file)
        label_dest_path = os.path.join(dest_labels_dir, label_file)
        image_file = label_file.replace('.txt', '.jpg')
        image_src_path = os.path.join(images_dir, image_file)
        image_dest_path = os.path.join(dest_images_dir, image_file)
        if os.path.exists(image_src_path):
            shutil.copy(label_src_path, label_dest_path)
            shutil.copy(image_src_path, image_dest_path)
            train_files.append(label_file)
        else:
            print(f"WARNING: File ảnh không tồn tại: {image_src_path}")
        
        for i in range(1, duplicate_factor):
            new_label_file = label_file.replace('.txt', f'_copy{i}.txt')
            new_image_file = image_file.replace('.jpg', f'_copy{i}.jpg')
            new_label_dest_path = os.path.join(dest_labels_dir, new_label_file)
            new_image_dest_path = os.path.join(dest_images_dir, new_image_file)
            shutil.copy(label_src_path, new_label_dest_path)
            if os.path.exists(image_src_path):
                shutil.copy(image_src_path, new_image_dest_path)
                train_files.append(new_label_file)
            else:
                print(f"WARNING: File ảnh không tồn tại: {image_src_path}")
    
    return train_files

# %%
dest_labels_dir_b = 'temp_b/labels'
dest_labels_dir_p = 'temp_p/labels'
dest_labels_dir_w = 'temp_w/labels'
dest_labels_dir_mix = 'temp_mix/labels'

dest_images_dir_b = 'temp_b/images'
dest_images_dir_p = 'temp_p/images'
dest_images_dir_w = 'temp_w/images'
dest_images_dir_mix = 'temp_mix/images'

duplicate_rare_classes(train_class_banana, labels_dir, images_dir, dest_labels_dir_b, dest_images_dir_b, duplicate_factor=2)
duplicate_rare_classes(train_class_pineapple, labels_dir, images_dir, dest_labels_dir_p, dest_images_dir_p, duplicate_factor=2)
duplicate_rare_classes(train_class_watermelon, labels_dir, images_dir, dest_labels_dir_w, dest_images_dir_w, duplicate_factor=2)
duplicate_rare_classes(train_mix_class, labels_dir, images_dir, dest_labels_dir_mix, dest_images_dir_mix, duplicate_factor=2)
# Out:
# ['0074691e66aa85c0_jpg.rf.2fc1e81bbe5377b89f9c912c52ff7905.txt',
#  '0074691e66aa85c0_jpg.rf.2fc1e81bbe5377b89f9c912c52ff7905_copy1.txt',
#  '00a70c466ad1fe24_jpg.rf.cf298c47a082719e705775c1ec343775.txt',
#  '00a70c466ad1fe24_jpg.rf.cf298c47a082719e705775c1ec343775_copy1.txt',
#  '00c1d2697deeaea1_jpg.rf.2231307959d5b30b34df054654821be2.txt',
#  '00c1d2697deeaea1_jpg.rf.2231307959d5b30b34df054654821be2_copy1.txt',
#  '00c1d2697deeaea1_jpg.rf.2390da6ff442cd3a6e8909983b89d2e6.txt',
#  '00c1d2697deeaea1_jpg.rf.2390da6ff442cd3a6e8909983b89d2e6_copy1.txt',
#  '00fd68005c636fda_jpg.rf.32869db931ff7ac0e41839024f2c7d79.txt',
#  '00fd68005c636fda_jpg.rf.32869db931ff7ac0e41839024f2c7d79_copy1.txt',
#  '00fd68005c636fda_jpg.rf.a299977af9decdbdf72144569d3265ec.txt',
#  '00fd68005c636fda_jpg.rf.a299977af9decdbdf72144569d3265ec_copy1.txt',
#  '0125268651daa59c_jpg.rf.1d58f76b6e8efc1435aa7ec133af0e39.txt',
#  '0125268651daa59c_jpg.rf.1d58f76b6e8efc1435aa7ec133af0e39_copy1.txt',
#  '0125268651daa59c_jpg.rf.9c23d30ac0a681e06d738f91891422de.txt',
#  '0125268651daa59c_jpg.rf.9c23d30ac0a681e06d738f91891422de_copy1.txt',
#  '01629ab4e5f0d759_jpg.rf.5191f2e6cbc9e8fa9d5a9828ee2ac54d.txt',
#  '01629ab4e5f0d759_jpg.rf.5191f2e6cbc9e8fa9d5a9828ee2ac54d_copy1.txt',
#  '01629ab4e5f0d759_jpg.rf.61e5566e95686dfaa3a9b6c8e3524521.txt',
#  '01629ab4e5f0d759_jpg.rf.61e5566e95686dfaa3a9b6c8e3524521_copy1.txt',
#  '01629ab4e5f0d759_jpg.rf.744d4a8d698a0e843e756a5fb3b5fb8f.txt',
#  '01629ab4e5f0d759_jpg.rf.744d4a8d698a0e843e756a5fb3b5fb8f_copy1.txt',
#  '01d567b45a25e202_jpg.rf.53000801c9b63d330f3d948f49815b87.txt',
#  '01d567b45a25e202_jpg.rf.53000801c9b63d330f3d948f49815b87_copy1.txt',
#  '01d567b45a25e202_jpg.rf.63d664d5e13e39450ecba4fc88999bfa.txt',
#  '01d567b45a25e202_jpg.rf.63d664d5e13e39450ecba4fc88999bfa_copy1.txt',
#  '01d567b45a25e202_jpg.rf.e3b44758a09fcac6ef0613da1e2ee385.txt',
#  '01d567b45a25e202_jpg.rf.e3b44758a09fcac6ef0613da1e2ee385_copy1.txt',
#  '01e6f55bc3f568b3_jpg.rf.5af9aeb1c80c5041f11fe473b7654aad.txt',
#  '01e6f55bc3f568b3_jpg.rf.5af9aeb1c80c5041f11fe473b7654aad_copy1.txt',
#  '01e6f55bc3f568b3_jpg.rf.5c57d6ccbc6385ba9c8f162d3e3b91fc.txt',
#  '01e6f55bc3f568b3_jpg.rf.5c57d6ccbc6385ba9c8f162d3e3b91fc_copy1.txt',
#  '01e6f55bc3f568b3_jpg.rf.5d86f7a8d77e91215cd4b3f25c047140.txt',
#  '01e6f55bc3f568b3_jpg.rf.5d86f7a8d77e91215cd4b3f25c047140_copy1.txt',
#  '0242b430afd08d2e_jpg.rf.cf199d39cad2d5c02c69aeb4214fa57a.txt',
#  '0242b430afd08d2e_jpg.rf.cf199d39cad2d5c02c69aeb4214fa57a_copy1.txt',
#  '02aa2ee596ee27f5_jpg.rf.10c696162e2d72933d17d2590d7e9a61.txt',
#  '02aa2ee596ee27f5_jpg.rf.10c696162e2d72933d17d2590d7e9a61_copy1.txt',
#  '02aa2ee596ee27f5_jpg.rf.b47883c7df71a49f00003aca92f0035e.txt',
#  '02aa2ee596ee27f5_jpg.rf.b47883c7df71a49f00003aca92f0035e_copy1.txt',
#  '02aa2ee596ee27f5_jpg.rf.baf76e02340a7550692fd6305bf5e3fe.txt',
#  '02aa2ee596ee27f5_jpg.rf.baf76e02340a7550692fd6305bf5e3fe_copy1.txt',
#  '02d4db21024cbe70_jpg.rf.13aff4ce1c1a2c49e43c762744733120.txt',
#  '02d4db21024cbe70_jpg.rf.13aff4ce1c1a2c49e43c762744733120_copy1.txt',
#  '02d4db21024cbe70_jpg.rf.d9776063d77a44a9f8f0c7645daa14c8.txt',
#  '02d4db21024cbe70_jpg.rf.d9776063d77a44a9f8f0c7645daa14c8_copy1.txt',
#  '02dfc9da1500fa0e_jpg.rf.37a158ee42dc14a52a9e6c11e981de6d.txt',
#  '02dfc9da1500fa0e_jpg.rf.37a158ee42dc14a52a9e6c11e981de6d_copy1.txt',
#  '02dfc9da1500fa0e_jpg.rf.3e7a03edd2bd68e2f4361b53624ba3e3.txt',
#  '02dfc9da1500fa0e_jpg.rf.3e7a03edd2bd68e2f4361b53624ba3e3_copy1.txt',
#  '02dfc9da1500fa0e_jpg.rf.ac63ca08af51c0bd6adcd2b7833b0d43.txt',
#  '02dfc9da1500fa0e_jpg.rf.ac63ca08af51c0bd6adcd2b7833b0d43_copy1.txt',
#  '02e5326e16421ba4_jpg.rf.18f882e0e130f7f7576ea1e1fdbdc0ff.txt',
#  '02e5326e16421ba4_jpg.rf.18f882e0e130f7f7576ea1e1fdbdc0ff_copy1.txt',
#  '02e5326e16421ba4_jpg.rf.435d02a51889b991a67f30484321407b.txt',
#  '02e5326e16421ba4_jpg.rf.435d02a51889b991a67f30484321407b_copy1.txt',
#  '02e5326e16421ba4_jpg.rf.a700df3e2df15cb0c2b2e3e17823f5bd.txt',
#  '02e5326e16421ba4_jpg.rf.a700df3e2df15cb0c2b2e3e17823f5bd_copy1.txt',
#  '031d3808721990da_jpg.rf.4d0abe5c5c890a476765a4f397a93845.txt',
#  '031d3808721990da_jpg.rf.4d0abe5c5c890a476765a4f397a93845_copy1.txt',
#  '031d3808721990da_jpg.rf.6278055e4f74f939024fa7f6069552c8.txt',
#  '031d3808721990da_jpg.rf.6278055e4f74f939024fa7f6069552c8_copy1.txt',
#  '031d3808721990da_jpg.rf.a5e489c13128ad40075bac7d9210b8c9.txt',
#  '031d3808721990da_jpg.rf.a5e489c13128ad40075bac7d9210b8c9_copy1.txt',
#  '0405611df46a676c_jpg.rf.67e8e96d2c7eed33701e8e96fd9b0246.txt',
#  '0405611df46a676c_jpg.rf.67e8e96d2c7eed33701e8e96fd9b0246_copy1.txt',
#  '045960cbda89e7c1_jpg.rf.9064f25df777f74d7b16278875e021ef.txt',
#  '045960cbda89e7c1_jpg.rf.9064f25df777f74d7b16278875e021ef_copy1.txt',
#  '055815f4e82ba1c6_jpg.rf.09b0c883c82af33920dbac00c80d8a0c.txt',
#  '055815f4e82ba1c6_jpg.rf.09b0c883c82af33920dbac00c80d8a0c_copy1.txt',
#  '055815f4e82ba1c6_jpg.rf.799c9de63661ae69a57318449f2ce610.txt',
#  '055815f4e82ba1c6_jpg.rf.799c9de63661ae69a57318449f2ce610_copy1.txt',
#  '055815f4e82ba1c6_jpg.rf.f015bcb30c86ade34bb36efbce0cb1fe.txt',
#  '055815f4e82ba1c6_jpg.rf.f015bcb30c86ade34bb36efbce0cb1fe_copy1.txt',
#  '067664613388e55e_jpg.rf.3fe37f81ba500b5a123b43beb49e5b1b.txt',
#  '067664613388e55e_jpg.rf.3fe37f81ba500b5a123b43beb49e5b1b_copy1.txt',
#  '067664613388e55e_jpg.rf.50891ce8fa5e839d43afe893c8ca5dee.txt',
#  '067664613388e55e_jpg.rf.50891ce8fa5e839d43afe893c8ca5dee_copy1.txt',
#  '067664613388e55e_jpg.rf.c307b9ff9752869068ab8e486d5c9e35.txt',
#  '067664613388e55e_jpg.rf.c307b9ff9752869068ab8e486d5c9e35_copy1.txt',
#  '069ee71de0456c3b_jpg.rf.7fab83284804ae7347e61e41c1a9a121.txt',
#  '069ee71de0456c3b_jpg.rf.7fab83284804ae7347e61e41c1a9a121_copy1.txt',
#  '076510c625071bb2_jpg.rf.1380f555fd1190d2cd0f1ba2c6532ce7.txt',
#  '076510c625071bb2_jpg.rf.1380f555fd1190d2cd0f1ba2c6532ce7_copy1.txt',
#  '076510c625071bb2_jpg.rf.2b2ad5f434bd7706d64a89d860cc9be9.txt',
#  '076510c625071bb2_jpg.rf.2b2ad5f434bd7706d64a89d860cc9be9_copy1.txt',
#  '076510c625071bb2_jpg.rf.cb09adbd9615ebbefe2b12887a1c44f3.txt',
#  '076510c625071bb2_jpg.rf.cb09adbd9615ebbefe2b12887a1c44f3_copy1.txt',
#  '092604e1d8923387_jpg.rf.03179f0d13f7941123a62bb7feb19431.txt',
#  '092604e1d8923387_jpg.rf.03179f0d13f7941123a62bb7feb19431_copy1.txt',
#  '092604e1d8923387_jpg.rf.51ba6eb19b73b797c349b7bd669271e1.txt',
#  '092604e1d8923387_jpg.rf.51ba6eb19b73b797c349b7bd669271e1_copy1.txt',
#  '092604e1d8923387_jpg.rf.a98af6f8727021e67437c3b9d5072d85.txt',
#  '092604e1d8923387_jpg.rf.a98af6f8727021e67437c3b9d5072d85_copy1.txt',
#  '092d59a67c16195a_jpg.rf.cfd25f79012c6cd2cb52b9ca55661cf9.txt',
#  '092d59a67c16195a_jpg.rf.cfd25f79012c6cd2cb52b9ca55661cf9_copy1.txt',
#  '092d59a67c16195a_jpg.rf.f6fe47a63793af79f860108d94cb79b4.txt',
#  '092d59a67c16195a_jpg.rf.f6fe47a63793af79f860108d94cb79b4_copy1.txt',
#  '0a4827f20c8aef05_jpg.rf.04be1c0687a3d0800fca4d224b6374df.txt',
#  '0a4827f20c8aef05_jpg.rf.04be1c0687a3d0800fca4d224b6374df_copy1.txt',
#  '0a4827f20c8aef05_jpg.rf.6ff9bb027afb57e50eb9269d1550afc8.txt',
#  '0a4827f20c8aef05_jpg.rf.6ff9bb027afb57e50eb9269d1550afc8_copy1.txt',
#  '0a4827f20c8aef05_jpg.rf.dc56d7a93d94a16951235ca76cc369c7.txt',
#  '0a4827f20c8aef05_jpg.rf.dc56d7a93d94a16951235ca76cc369c7_copy1.txt',
#  '0e6227547e820ae2_jpg.rf.a29a87c256bc1d0c2b8db610389a953e.txt',
#  '0e6227547e820ae2_jpg.rf.a29a87c256bc1d0c2b8db610389a953e_copy1.txt',
#  '0e6227547e820ae2_jpg.rf.e249d1837a4e0178f577b4a97393f11b.txt',
#  '0e6227547e820ae2_jpg.rf.e249d1837a4e0178f577b4a97393f11b_copy1.txt',
#  '0e6227547e820ae2_jpg.rf.f10baa7e073c82202cbbe088f1e0645f.txt',
#  '0e6227547e820ae2_jpg.rf.f10baa7e073c82202cbbe088f1e0645f_copy1.txt',
#  '0eaaa0f4beec10f6_jpg.rf.1ee293379a793b032380edc7c518552a.txt',
#  '0eaaa0f4beec10f6_jpg.rf.1ee293379a793b032380edc7c518552a_copy1.txt',
#  '0eaaa0f4beec10f6_jpg.rf.e0303d1a9be20036e00e3c471f607de1.txt',
#  '0eaaa0f4beec10f6_jpg.rf.e0303d1a9be20036e00e3c471f607de1_copy1.txt',
#  '0eaaa0f4beec10f6_jpg.rf.f5fb492b07a222f590f8822192b5419f.txt',
#  '0eaaa0f4beec10f6_jpg.rf.f5fb492b07a222f590f8822192b5419f_copy1.txt',
#  '0ff437803b1cb719_jpg.rf.1a6fdc913f5cba4e313230bceccc23fb.txt',
#  '0ff437803b1cb719_jpg.rf.1a6fdc913f5cba4e313230bceccc23fb_copy1.txt',
#  '0ff437803b1cb719_jpg.rf.2ea28f6ac4975dc581ebc4bce7e134ca.txt',
#  '0ff437803b1cb719_jpg.rf.2ea28f6ac4975dc581ebc4bce7e134ca_copy1.txt',
#  '100940397939f11e_jpg.rf.2b88e62432548c61fac1aaee192509e1.txt',
#  '100940397939f11e_jpg.rf.2b88e62432548c61fac1aaee192509e1_copy1.txt',
#  '100940397939f11e_jpg.rf.d33efba47200d6970aefc9ca55e42939.txt',
#  '100940397939f11e_jpg.rf.d33efba47200d6970aefc9ca55e42939_copy1.txt',
#  '12d935a6b4f1ec53_jpg.rf.1a7b78bbb4204c4169cb3d8e7be585d8.txt',
#  '12d935a6b4f1ec53_jpg.rf.1a7b78bbb4204c4169cb3d8e7be585d8_copy1.txt',
#  '12d935a6b4f1ec53_jpg.rf.b38dda2464fe526287a0790c9f90e9f9.txt',
#  '12d935a6b4f1ec53_jpg.rf.b38dda2464fe526287a0790c9f90e9f9_copy1.txt',
#  '12d935a6b4f1ec53_jpg.rf.c5778ad588d04114e89a9b5f7163feb2.txt',
#  '12d935a6b4f1ec53_jpg.rf.c5778ad588d04114e89a9b5f7163feb2_copy1.txt',
#  '132fc68df66515b0_jpg.rf.419a70d944076117ff7125a88d6fcecb.txt',
#  '132fc68df66515b0_jpg.rf.419a70d944076117ff7125a88d6fcecb_copy1.txt',
#  '132fc68df66515b0_jpg.rf.c7178f6d1e7d7ecfb359b807b6ee4106.txt',
#  '132fc68df66515b0_jpg.rf.c7178f6d1e7d7ecfb359b807b6ee4106_copy1.txt',
#  '132fc68df66515b0_jpg.rf.dbf51d35e1e0f13634e790df08ba11db.txt',
#  '132fc68df66515b0_jpg.rf.dbf51d35e1e0f13634e790df08ba11db_copy1.txt',
#  '156456a6e3ebe7d9_jpg.rf.4f912a30588814ade98e98e0d501290c.txt',
#  '156456a6e3ebe7d9_jpg.rf.4f912a30588814ade98e98e0d501290c_copy1.txt',
#  '15cc05949c6a175c_jpg.rf.2fb2c735e5c565a822f477568787516a.txt',
#  '15cc05949c6a175c_jpg.rf.2fb2c735e5c565a822f477568787516a_copy1.txt',
#  '15cc05949c6a175c_jpg.rf.9834ab9d8acb8b382de8f2431430fd0e.txt',
#  '15cc05949c6a175c_jpg.rf.9834ab9d8acb8b382de8f2431430fd0e_copy1.txt',
#  '15cc05949c6a175c_jpg.rf.c8e8c097a9bbbd863994b4a1c6adaa65.txt',
#  '15cc05949c6a175c_jpg.rf.c8e8c097a9bbbd863994b4a1c6adaa65_copy1.txt',
#  '15f4bb30342fc1cb_jpg.rf.70f50be82fa61d87704c185414a8c9cc.txt',
#  '15f4bb30342fc1cb_jpg.rf.70f50be82fa61d87704c185414a8c9cc_copy1.txt',
#  '15f4bb30342fc1cb_jpg.rf.c8d8b38d661ac61b6120da5e57be132e.txt',
#  '15f4bb30342fc1cb_jpg.rf.c8d8b38d661ac61b6120da5e57be132e_copy1.txt',
#  '17aef69068f3bba9_jpg.rf.9cc36b045d4e6046f5f0306dd55d0d22.txt',
#  '17aef69068f3bba9_jpg.rf.9cc36b045d4e6046f5f0306dd55d0d22_copy1.txt',
#  '17aef69068f3bba9_jpg.rf.cc9d977fb0972eeb4141fbd04cbaecb6.txt',
#  '17aef69068f3bba9_jpg.rf.cc9d977fb0972eeb4141fbd04cbaecb6_copy1.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.09cd28418d70e7429b92bc6edefb11e5.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.09cd28418d70e7429b92bc6edefb11e5_copy1.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.665062e479662d119ff7051059d77d03.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.665062e479662d119ff7051059d77d03_copy1.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.87533493f3bf5d55eb95ce5f11f33b39.txt',
#  '1bc3d9027fc0e4b2_jpg.rf.87533493f3bf5d55eb95ce5f11f33b39_copy1.txt',
#  '1bfdec75635e4765_jpg.rf.75eb68edc25f525d184a0df6d765bd60.txt',
#  '1bfdec75635e4765_jpg.rf.75eb68edc25f525d184a0df6d765bd60_copy1.txt',
#  '1bfdec75635e4765_jpg.rf.879503225a946e348485e42602143070.txt',
#  '1bfdec75635e4765_jpg.rf.879503225a946e348485e42602143070_copy1.txt',
#  '1ca53cd88fe85649_jpg.rf.66e1ef87d504f55de84ce0dc1a2a1c78.txt',
#  '1ca53cd88fe85649_jpg.rf.66e1ef87d504f55de84ce0dc1a2a1c78_copy1.txt',
#  '1e2b090f4f0090ce_jpg.rf.1c218767d1d85b06d1542ec32ad0209e.txt',
#  '1e2b090f4f0090ce_jpg.rf.1c218767d1d85b06d1542ec32ad0209e_copy1.txt',
#  '1e2b090f4f0090ce_jpg.rf.e3ff7239a1041f922b4663413ada062c.txt',
#  '1e2b090f4f0090ce_jpg.rf.e3ff7239a1041f922b4663413ada062c_copy1.txt',
#  '1e2b090f4f0090ce_jpg.rf.e43c794c056fd47c672af2aa05875942.txt',
#  '1e2b090f4f0090ce_jpg.rf.e43c794c056fd47c672af2aa05875942_copy1.txt',
#  '212f29ce83ba711b_jpg.rf.2aad80d57ac178b350c609e9117da26e.txt',
#  '212f29ce83ba711b_jpg.rf.2aad80d57ac178b350c609e9117da26e_copy1.txt',
#  '212f29ce83ba711b_jpg.rf.3542861042f5f57133ff065ffbb8b5be.txt',
#  '212f29ce83ba711b_jpg.rf.3542861042f5f57133ff065ffbb8b5be_copy1.txt',
#  '212f29ce83ba711b_jpg.rf.f5a344896620f8635506558fad34971f.txt',
#  '212f29ce83ba711b_jpg.rf.f5a344896620f8635506558fad34971f_copy1.txt',
#  '22be77f706b5f9f6_jpg.rf.d77a9180838144165b9a6be7c75d7a2c.txt',
#  '22be77f706b5f9f6_jpg.rf.d77a9180838144165b9a6be7c75d7a2c_copy1.txt',
#  '23c2ca2c1f00fcc2_jpg.rf.7256356f0ced991b624716394465c406.txt',
#  '23c2ca2c1f00fcc2_jpg.rf.7256356f0ced991b624716394465c406_copy1.txt',
#  '23c2ca2c1f00fcc2_jpg.rf.de9fb8d6d850223e242ee055b31042c6.txt',
#  '23c2ca2c1f00fcc2_jpg.rf.de9fb8d6d850223e242ee055b31042c6_copy1.txt',
#  '23cd5401edecf974_jpg.rf.b0b51793af4fa01cc8ae944a30e3c14d.txt',
#  '23cd5401edecf974_jpg.rf.b0b51793af4fa01cc8ae944a30e3c14d_copy1.txt',
#  '251c49d623e62eeb_jpg.rf.0f0700480f663229f0a940d25564cc86.txt',
#  '251c49d623e62eeb_jpg.rf.0f0700480f663229f0a940d25564cc86_copy1.txt',
#  '251c49d623e62eeb_jpg.rf.3d11942da662c1adee537c62a1509b1d.txt',
#  '251c49d623e62eeb_jpg.rf.3d11942da662c1adee537c62a1509b1d_copy1.txt',
#  '251c49d623e62eeb_jpg.rf.84e49257fe07e1f5a3960076d18b4fd5.txt',
#  '251c49d623e62eeb_jpg.rf.84e49257fe07e1f5a3960076d18b4fd5_copy1.txt',
#  '28635c1b48719e52_jpg.rf.2cd77f489b347263865ae54387d3f48f.txt',
#  '28635c1b48719e52_jpg.rf.2cd77f489b347263865ae54387d3f48f_copy1.txt',
#  '29fbb981cf20bc36_jpg.rf.31259a120234e4a3508bf724881325d9.txt',
#  '29fbb981cf20bc36_jpg.rf.31259a120234e4a3508bf724881325d9_copy1.txt',
#  '29fbb981cf20bc36_jpg.rf.4149540418d2f943b2541fbab9af7bac.txt',
#  '29fbb981cf20bc36_jpg.rf.4149540418d2f943b2541fbab9af7bac_copy1.txt',
#  '29fbb981cf20bc36_jpg.rf.f0441e815bd1edb5d3e7e336a22416b2.txt',
#  '29fbb981cf20bc36_jpg.rf.f0441e815bd1edb5d3e7e336a22416b2_copy1.txt',
#  '2f0456842c786ff5_jpg.rf.37ab12817700ed115c8513d84d5b2b81.txt',
#  '2f0456842c786ff5_jpg.rf.37ab12817700ed115c8513d84d5b2b81_copy1.txt',
#  '2f0456842c786ff5_jpg.rf.55f51a92629733bbe4f2d2bc94c3679e.txt',
#  '2f0456842c786ff5_jpg.rf.55f51a92629733bbe4f2d2bc94c3679e_copy1.txt',
#  '2f0456842c786ff5_jpg.rf.9490eedfd441192c49ade884589f4424.txt',
#  '2f0456842c786ff5_jpg.rf.9490eedfd441192c49ade884589f4424_copy1.txt',
#  '315971bda5b0ab34_jpg.rf.64b13c5658003fe0c2fb5cf6ef6bf4db.txt',
#  '315971bda5b0ab34_jpg.rf.64b13c5658003fe0c2fb5cf6ef6bf4db_copy1.txt',
#  '315971bda5b0ab34_jpg.rf.86d0cb31258d34aef856dff03a69e764.txt',
#  '315971bda5b0ab34_jpg.rf.86d0cb31258d34aef856dff03a69e764_copy1.txt',
#  '315971bda5b0ab34_jpg.rf.a8e0d022da874ac9d74dc16a1fb2a46b.txt',
#  '315971bda5b0ab34_jpg.rf.a8e0d022da874ac9d74dc16a1fb2a46b_copy1.txt',
#  '32797e15988da36e_jpg.rf.1772543d6f39d25dc739f8f8e79a210d.txt',
#  '32797e15988da36e_jpg.rf.1772543d6f39d25dc739f8f8e79a210d_copy1.txt',
#  '353ce3f0e995ff30_jpg.rf.6018d5fb8a04da6540dbb9b91fca472e.txt',
#  '353ce3f0e995ff30_jpg.rf.6018d5fb8a04da6540dbb9b91fca472e_copy1.txt',
#  '353ce3f0e995ff30_jpg.rf.6718a1c48e6e9ccd297879736229752b.txt',
#  '353ce3f0e995ff30_jpg.rf.6718a1c48e6e9ccd297879736229752b_copy1.txt',
#  '3a0f98128471086d_jpg.rf.678135e98a8d5f44bc4710210616a4b8.txt',
#  '3a0f98128471086d_jpg.rf.678135e98a8d5f44bc4710210616a4b8_copy1.txt',
#  '3a0f98128471086d_jpg.rf.87c83466266d78d28e8fa377e88e1079.txt',
#  '3a0f98128471086d_jpg.rf.87c83466266d78d28e8fa377e88e1079_copy1.txt',
#  '3b4ac20681abb791_jpg.rf.6ee397568276ad07bb3bd0c72c0eb31d.txt',
#  '3b4ac20681abb791_jpg.rf.6ee397568276ad07bb3bd0c72c0eb31d_copy1.txt',
#  '3b4ac20681abb791_jpg.rf.6f0202db448689b2bcff1d5016aeac3e.txt',
#  '3b4ac20681abb791_jpg.rf.6f0202db448689b2bcff1d5016aeac3e_copy1.txt',
#  '3b4ac20681abb791_jpg.rf.e648a2fa67bece363f528efbafd4bbcb.txt',
#  '3b4ac20681abb791_jpg.rf.e648a2fa67bece363f528efbafd4bbcb_copy1.txt',
#  '3c420f8ab88a11d9_jpg.rf.1cb6a29accc4f5da6eb757b5ebc034e3.txt',
#  '3c420f8ab88a11d9_jpg.rf.1cb6a29accc4f5da6eb757b5ebc034e3_copy1.txt',
#  '3fa1fe3f26c80fde_jpg.rf.232f534ae11db3dd3d471040c6cec58f.txt',
#  '3fa1fe3f26c80fde_jpg.rf.232f534ae11db3dd3d471040c6cec58f_copy1.txt',
#  '3fa1fe3f26c80fde_jpg.rf.8391d21a3f2ceb2f40228f9ebc5603b4.txt',
#  '3fa1fe3f26c80fde_jpg.rf.8391d21a3f2ceb2f40228f9ebc5603b4_copy1.txt',
#  '3fa1fe3f26c80fde_jpg.rf.cfb9147393d8a8d42e80294ade8fd038.txt',
#  '3fa1fe3f26c80fde_jpg.rf.cfb9147393d8a8d42e80294ade8fd038_copy1.txt',
#  '3fa3b754c7ee06e0_jpg.rf.e60325d6415ffd9ae9d46173dcaeefbd.txt',
#  '3fa3b754c7ee06e0_jpg.rf.e60325d6415ffd9ae9d46173dcaeefbd_copy1.txt',
#  '40a01343ff3aab2e_jpg.rf.3105908b75099e81aaece94ab1b9aed7.txt',
#  '40a01343ff3aab2e_jpg.rf.3105908b75099e81aaece94ab1b9aed7_copy1.txt',
#  '40a01343ff3aab2e_jpg.rf.cdae8acbb87a79fea7ec992b661b2472.txt',
#  '40a01343ff3aab2e_jpg.rf.cdae8acbb87a79fea7ec992b661b2472_copy1.txt',
#  '40a01343ff3aab2e_jpg.rf.f3b9e2d45546ab878fad5134dacbf35f.txt',
#  '40a01343ff3aab2e_jpg.rf.f3b9e2d45546ab878fad5134dacbf35f_copy1.txt',
#  '410690d34ff17eb4_jpg.rf.79a7bf6cfaf750db4be733e2f6f975ee.txt',
#  '410690d34ff17eb4_jpg.rf.79a7bf6cfaf750db4be733e2f6f975ee_copy1.txt',
#  '410690d34ff17eb4_jpg.rf.be61237440bbb75a060f57e0e0ce54f6.txt',
#  '410690d34ff17eb4_jpg.rf.be61237440bbb75a060f57e0e0ce54f6_copy1.txt',
#  '410690d34ff17eb4_jpg.rf.e6a437d8f0873f263061d6f77b76f84d.txt',
#  '410690d34ff17eb4_jpg.rf.e6a437d8f0873f263061d6f77b76f84d_copy1.txt',
#  '4177a51592ce653b_jpg.rf.1b5853dd617fc6a595f994567e45ade6.txt',
#  '4177a51592ce653b_jpg.rf.1b5853dd617fc6a595f994567e45ade6_copy1.txt',
#  '4177a51592ce653b_jpg.rf.451af770f4c80b90193849dde35984cc.txt',
#  '4177a51592ce653b_jpg.rf.451af770f4c80b90193849dde35984cc_copy1.txt',
#  '4177a51592ce653b_jpg.rf.54a65f6523406a281d13308b07988724.txt',
#  '4177a51592ce653b_jpg.rf.54a65f6523406a281d13308b07988724_copy1.txt',
#  '44a791b203005b33_jpg.rf.cdf5120b2000d21e2ac58de5c612fec5.txt',
#  '44a791b203005b33_jpg.rf.cdf5120b2000d21e2ac58de5c612fec5_copy1.txt',
#  '44a791b203005b33_jpg.rf.ec548afe86a936a680db119de00a4544.txt',
#  '44a791b203005b33_jpg.rf.ec548afe86a936a680db119de00a4544_copy1.txt',
#  '4cce4072af3e3b2f_jpg.rf.3fce4ca9772ffb2f7ff1bfc48f192e40.txt',
#  '4cce4072af3e3b2f_jpg.rf.3fce4ca9772ffb2f7ff1bfc48f192e40_copy1.txt',
#  '4cce4072af3e3b2f_jpg.rf.8ba9e5a8ef7311bb2009da0713c19a68.txt',
#  '4cce4072af3e3b2f_jpg.rf.8ba9e5a8ef7311bb2009da0713c19a68_copy1.txt',
#  '4cce4072af3e3b2f_jpg.rf.ac99f491921ac3a210ddf6f46a9d3c36.txt',
#  '4cce4072af3e3b2f_jpg.rf.ac99f491921ac3a210ddf6f46a9d3c36_copy1.txt',
#  '4d40949d16a2e58e_jpg.rf.c55236838550b35410db5e9cfef970cb.txt',
#  '4d40949d16a2e58e_jpg.rf.c55236838550b35410db5e9cfef970cb_copy1.txt',
#  '51eb96d955f19d7f_jpg.rf.eaa4b481acbdde70f79c568e58a95d3c.txt',
#  '51eb96d955f19d7f_jpg.rf.eaa4b481acbdde70f79c568e58a95d3c_copy1.txt',
#  '532fdd384c1955ea_jpg.rf.3e610d6c409ab0a6985e0375ad757f26.txt',
#  '532fdd384c1955ea_jpg.rf.3e610d6c409ab0a6985e0375ad757f26_copy1.txt',
#  '532fdd384c1955ea_jpg.rf.407f8d5784ec553e71dd3305cca6e99b.txt',
#  '532fdd384c1955ea_jpg.rf.407f8d5784ec553e71dd3305cca6e99b_copy1.txt',
#  '532fdd384c1955ea_jpg.rf.e2023cf84d0aff4420a088b4b56e27b8.txt',
#  '532fdd384c1955ea_jpg.rf.e2023cf84d0aff4420a088b4b56e27b8_copy1.txt',
#  '5444b98b94cd117c_jpg.rf.32c160b97a714cce1a034cc26308de6e.txt',
#  '5444b98b94cd117c_jpg.rf.32c160b97a714cce1a034cc26308de6e_copy1.txt',
#  '578cf0b5be3ce649_jpg.rf.1c6a7911c4f15c9aa972eebbf280d5a6.txt',
#  '578cf0b5be3ce649_jpg.rf.1c6a7911c4f15c9aa972eebbf280d5a6_copy1.txt',
#  '578cf0b5be3ce649_jpg.rf.45ada9d3d6faae466c047bbc03c8d0a8.txt',
#  '578cf0b5be3ce649_jpg.rf.45ada9d3d6faae466c047bbc03c8d0a8_copy1.txt',
#  '578cf0b5be3ce649_jpg.rf.c026c4927a6e17b2acd08192436cec74.txt',
#  '578cf0b5be3ce649_jpg.rf.c026c4927a6e17b2acd08192436cec74_copy1.txt',
#  '5f955198afce6d0a_jpg.rf.096f404d2b411b44f290d932e5f18f57.txt',
#  '5f955198afce6d0a_jpg.rf.096f404d2b411b44f290d932e5f18f57_copy1.txt',
#  '5f955198afce6d0a_jpg.rf.a91cd1950b382703dc3ccdae1b1d74fe.txt',
#  '5f955198afce6d0a_jpg.rf.a91cd1950b382703dc3ccdae1b1d74fe_copy1.txt',
#  '5f955198afce6d0a_jpg.rf.b0905b12bd76cb03d529268fcd1be398.txt',
#  '5f955198afce6d0a_jpg.rf.b0905b12bd76cb03d529268fcd1be398_copy1.txt',
#  '5fafb74fae70df30_jpg.rf.699c11601a0e0f7abe5e1605c283abbb.txt',
#  '5fafb74fae70df30_jpg.rf.699c11601a0e0f7abe5e1605c283abbb_copy1.txt',
#  '5fafb74fae70df30_jpg.rf.f58ad5ff718bfe612f825d09910de30e.txt',
#  '5fafb74fae70df30_jpg.rf.f58ad5ff718bfe612f825d09910de30e_copy1.txt',
#  '60e323b9155aeab8_jpg.rf.0992a64a485ccdc6d52528cf651ea1ea.txt',
#  '60e323b9155aeab8_jpg.rf.0992a64a485ccdc6d52528cf651ea1ea_copy1.txt',
#  '60e323b9155aeab8_jpg.rf.75d496c1867a031aef56ef80f81ac278.txt',
#  '60e323b9155aeab8_jpg.rf.75d496c1867a031aef56ef80f81ac278_copy1.txt',
#  '621c3ef8f40a47ca_jpg.rf.56015b54adff3619a541a0c0be0cfdbe.txt',
#  '621c3ef8f40a47ca_jpg.rf.56015b54adff3619a541a0c0be0cfdbe_copy1.txt',
#  '621c3ef8f40a47ca_jpg.rf.5a090b5cddca34c12949efa330ffa292.txt',
#  '621c3ef8f40a47ca_jpg.rf.5a090b5cddca34c12949efa330ffa292_copy1.txt',
#  '621c3ef8f40a47ca_jpg.rf.880958c5042a80f0d46ab5493ce2c6d1.txt',
#  '621c3ef8f40a47ca_jpg.rf.880958c5042a80f0d46ab5493ce2c6d1_copy1.txt',
#  '63938f023ccfedbf_jpg.rf.1aace4099ae8f71b662019db65e2ac94.txt',
#  '63938f023ccfedbf_jpg.rf.1aace4099ae8f71b662019db65e2ac94_copy1.txt',
#  '63938f023ccfedbf_jpg.rf.2a57f8057684db7b09d208924d285f7a.txt',
#  '63938f023ccfedbf_jpg.rf.2a57f8057684db7b09d208924d285f7a_copy1.txt',
#  '63938f023ccfedbf_jpg.rf.843aec2a26b59cd53599384ac694627b.txt',
#  '63938f023ccfedbf_jpg.rf.843aec2a26b59cd53599384ac694627b_copy1.txt',
#  '64b93fdec8487a1c_jpg.rf.69c68f6ebfda14c232312c12a04f7795.txt',
#  '64b93fdec8487a1c_jpg.rf.69c68f6ebfda14c232312c12a04f7795_copy1.txt',
#  '66d104fce2ff24da_jpg.rf.4fd69d3b63a0854116a32600c65ac91b.txt',
#  '66d104fce2ff24da_jpg.rf.4fd69d3b63a0854116a32600c65ac91b_copy1.txt',
#  '6a235e1f6981d4f1_jpg.rf.f9eb6c1b2539a7594ec10c5465ffb40b.txt',
#  '6a235e1f6981d4f1_jpg.rf.f9eb6c1b2539a7594ec10c5465ffb40b_copy1.txt',
#  '6c575166603ecf61_jpg.rf.40a75df0ecdf5900f213328b2c968980.txt',
#  '6c575166603ecf61_jpg.rf.40a75df0ecdf5900f213328b2c968980_copy1.txt',
#  '70c501839edf5523_jpg.rf.850cdf92a10ea0ecf973491c32f38bc4.txt',
#  '70c501839edf5523_jpg.rf.850cdf92a10ea0ecf973491c32f38bc4_copy1.txt',
#  '70c501839edf5523_jpg.rf.d1fe193eafa362cfd9af68aeb15da872.txt',
#  '70c501839edf5523_jpg.rf.d1fe193eafa362cfd9af68aeb15da872_copy1.txt',
#  '71a1cf8408afce76_jpg.rf.f2057bc112889e5a43c43062cd95ce53.txt',
#  '71a1cf8408afce76_jpg.rf.f2057bc112889e5a43c43062cd95ce53_copy1.txt',
#  '7243bb39ae8d770d_jpg.rf.a4419a3f268941317cf33f86e7e27cd2.txt',
#  '7243bb39ae8d770d_jpg.rf.a4419a3f268941317cf33f86e7e27cd2_copy1.txt',
#  '7c1604a476909f5f_jpg.rf.0360f180c5dcf8d5f6589fe63199e3ec.txt',
#  '7c1604a476909f5f_jpg.rf.0360f180c5dcf8d5f6589fe63199e3ec_copy1.txt',
#  '7c1604a476909f5f_jpg.rf.91ed08c5bd7bb67c8c790efd796ff36c.txt',
#  '7c1604a476909f5f_jpg.rf.91ed08c5bd7bb67c8c790efd796ff36c_copy1.txt',
#  '7c1604a476909f5f_jpg.rf.a16fe4ac18477547de8bf8184ed89a78.txt',
#  '7c1604a476909f5f_jpg.rf.a16fe4ac18477547de8bf8184ed89a78_copy1.txt',
#  '7ca9e5260a5885d4_jpg.rf.4c30606ec5a0f7af13040c9b534268c3.txt',
#  '7ca9e5260a5885d4_jpg.rf.4c30606ec5a0f7af13040c9b534268c3_copy1.txt',
#  '7ca9e5260a5885d4_jpg.rf.82110dbfd145c56ee854b14f3e65b2eb.txt',
#  '7ca9e5260a5885d4_jpg.rf.82110dbfd145c56ee854b14f3e65b2eb_copy1.txt',
#  '7e436e5bb7f3b1cd_jpg.rf.a53ca406ccee38672398b47b198e39eb.txt',
#  '7e436e5bb7f3b1cd_jpg.rf.a53ca406ccee38672398b47b198e39eb_copy1.txt',
#  '8369a3adafaf9a1e_jpg.rf.5c05b7da09f4b0662c25fce017857784.txt',
#  '8369a3adafaf9a1e_jpg.rf.5c05b7da09f4b0662c25fce017857784_copy1.txt',
#  '8369a3adafaf9a1e_jpg.rf.afa50718ba67ba578b16392713d13adb.txt',
#  '8369a3adafaf9a1e_jpg.rf.afa50718ba67ba578b16392713d13adb_copy1.txt',
#  '8369a3adafaf9a1e_jpg.rf.dba07db8537c0eeafec0e6f98ff02581.txt',
#  '8369a3adafaf9a1e_jpg.rf.dba07db8537c0eeafec0e6f98ff02581_copy1.txt',
#  '90e92e44cc3e3170_jpg.rf.673c88ed21775891c0f5ca6e62f8ac1c.txt',
#  '90e92e44cc3e3170_jpg.rf.673c88ed21775891c0f5ca6e62f8ac1c_copy1.txt',
#  '90e92e44cc3e3170_jpg.rf.af99db346fd1ec28ce4eeb618b02ee81.txt',
#  '90e92e44cc3e3170_jpg.rf.af99db346fd1ec28ce4eeb618b02ee81_copy1.txt',
#  '90e92e44cc3e3170_jpg.rf.be464ef5a6ecb8e1800c326b8873aeab.txt',
#  '90e92e44cc3e3170_jpg.rf.be464ef5a6ecb8e1800c326b8873aeab_copy1.txt',
#  '92a86c1b57b33528_jpg.rf.3ecefa53389f58894169dae2254bb4d8.txt',
#  '92a86c1b57b33528_jpg.rf.3ecefa53389f58894169dae2254bb4d8_copy1.txt',
#  '92a86c1b57b33528_jpg.rf.51f80f60572a3ed29e542967951e632e.txt',
#  '92a86c1b57b33528_jpg.rf.51f80f60572a3ed29e542967951e632e_copy1.txt',
#  '9bc50442e59ff921_jpg.rf.e63ea08eb575613f47faad66f89db6b0.txt',
#  '9bc50442e59ff921_jpg.rf.e63ea08eb575613f47faad66f89db6b0_copy1.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.02b9749dbdefba612ab2f420152de61b.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.02b9749dbdefba612ab2f420152de61b_copy1.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.287b7b108ca5129da9a7bf991e8f8009.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.287b7b108ca5129da9a7bf991e8f8009_copy1.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.c1773db6975538567ae9256884f415c1.txt',
#  '9ebc4544e2ef3c0c_jpg.rf.c1773db6975538567ae9256884f415c1_copy1.txt',
#  'a1a21212960595ca_jpg.rf.341de23338cd52244203c1080b2dfcdb.txt',
#  'a1a21212960595ca_jpg.rf.341de23338cd52244203c1080b2dfcdb_copy1.txt',
#  'a1a21212960595ca_jpg.rf.aa580288f6f461d062b49ca7b4a3f897.txt',
#  'a1a21212960595ca_jpg.rf.aa580288f6f461d062b49ca7b4a3f897_copy1.txt',
#  'a1a21212960595ca_jpg.rf.e036f05f1f29d99f53fea696767ce736.txt',
#  'a1a21212960595ca_jpg.rf.e036f05f1f29d99f53fea696767ce736_copy1.txt',
#  'a5e04767fb8b0afa_jpg.rf.16c29ceb293fb226454bf5b974668766.txt',
#  'a5e04767fb8b0afa_jpg.rf.16c29ceb293fb226454bf5b974668766_copy1.txt',
#  'a5e04767fb8b0afa_jpg.rf.d3e2114ccb49924a9ffc3a419aecdae1.txt',
#  'a5e04767fb8b0afa_jpg.rf.d3e2114ccb49924a9ffc3a419aecdae1_copy1.txt',
#  'a5e04767fb8b0afa_jpg.rf.dd48e0343af68e36932309f6d718f7ca.txt',
#  'a5e04767fb8b0afa_jpg.rf.dd48e0343af68e36932309f6d718f7ca_copy1.txt',
#  'a69f8792bd8ae5d5_jpg.rf.892afe93ab600bfa42414033ad319714.txt',
#  'a69f8792bd8ae5d5_jpg.rf.892afe93ab600bfa42414033ad319714_copy1.txt',
#  'a69f8792bd8ae5d5_jpg.rf.d844af5cc58223d29b39cc4c4cce796f.txt',
#  'a69f8792bd8ae5d5_jpg.rf.d844af5cc58223d29b39cc4c4cce796f_copy1.txt',
#  'a69f8792bd8ae5d5_jpg.rf.dff135a6b846b1ca2a3d7d0ef5cacd76.txt',
#  'a69f8792bd8ae5d5_jpg.rf.dff135a6b846b1ca2a3d7d0ef5cacd76_copy1.txt',
#  'a6e471eb1320e0ee_jpg.rf.37a61c5fe113473cd446f50b80302e76.txt',
#  'a6e471eb1320e0ee_jpg.rf.37a61c5fe113473cd446f50b80302e76_copy1.txt',
#  'a92eb06a935fd628_jpg.rf.25601001a6374391b361016d180e287a.txt',
#  'a92eb06a935fd628_jpg.rf.25601001a6374391b361016d180e287a_copy1.txt',
#  'a92eb06a935fd628_jpg.rf.a4038c162c82fefb9d55c1488d24a449.txt',
#  'a92eb06a935fd628_jpg.rf.a4038c162c82fefb9d55c1488d24a449_copy1.txt',
#  'abbaaa72796bfb02_jpg.rf.f3f538706a95b5dcff518d0698d74ecb.txt',
#  'abbaaa72796bfb02_jpg.rf.f3f538706a95b5dcff518d0698d74ecb_copy1.txt',
#  'ac4836e92d94b93f_jpg.rf.4fe589bcccbad13e0cf3519a296b6374.txt',
#  'ac4836e92d94b93f_jpg.rf.4fe589bcccbad13e0cf3519a296b6374_copy1.txt',
#  'ac4836e92d94b93f_jpg.rf.67feb6d92ab3a2edcf3a5d295b8a01d8.txt',
#  'ac4836e92d94b93f_jpg.rf.67feb6d92ab3a2edcf3a5d295b8a01d8_copy1.txt',
#  'ac4836e92d94b93f_jpg.rf.ae0b3ca7ce45d7841692f86f1538be8a.txt',
#  'ac4836e92d94b93f_jpg.rf.ae0b3ca7ce45d7841692f86f1538be8a_copy1.txt',
#  'ac71b688372afd49_jpg.rf.22e02ef04cee3debc125a1c2b5ad5462.txt',
#  'ac71b688372afd49_jpg.rf.22e02ef04cee3debc125a1c2b5ad5462_copy1.txt',
#  'ac71b688372afd49_jpg.rf.9003c7b07be6cba9c88f334f8c7c9264.txt',
#  'ac71b688372afd49_jpg.rf.9003c7b07be6cba9c88f334f8c7c9264_copy1.txt',
#  'ac71b688372afd49_jpg.rf.e4cdacc61ccfb6a219e759470fc1482a.txt',
#  'ac71b688372afd49_jpg.rf.e4cdacc61ccfb6a219e759470fc1482a_copy1.txt',
#  'ac917b98f00187ad_jpg.rf.2b75a785674277597e5ac4ad4985002c.txt',
#  'ac917b98f00187ad_jpg.rf.2b75a785674277597e5ac4ad4985002c_copy1.txt',
#  'aef06e3a2dd9f081_jpg.rf.086f2aa9610d2f0d8c7cee1d0712f26f.txt',
#  'aef06e3a2dd9f081_jpg.rf.086f2aa9610d2f0d8c7cee1d0712f26f_copy1.txt',
#  'aef06e3a2dd9f081_jpg.rf.91427e8f4557dd97a6bbdddac732b4f1.txt',
#  'aef06e3a2dd9f081_jpg.rf.91427e8f4557dd97a6bbdddac732b4f1_copy1.txt',
#  'b1ce6250dad71e9e_jpg.rf.7e6c9c589059abf3b20ee61f404d1b61.txt',
#  'b1ce6250dad71e9e_jpg.rf.7e6c9c589059abf3b20ee61f404d1b61_copy1.txt',
#  'b1ce6250dad71e9e_jpg.rf.87870d483fd87825a1c1fefbd2b2163b.txt',
#  'b1ce6250dad71e9e_jpg.rf.87870d483fd87825a1c1fefbd2b2163b_copy1.txt',
#  'b1ce6250dad71e9e_jpg.rf.cfe224accd5c048cbbb9f210c116753e.txt',
#  'b1ce6250dad71e9e_jpg.rf.cfe224accd5c048cbbb9f210c116753e_copy1.txt',
#  'b5cf54f877f2e5b8_jpg.rf.50522416f09cd8269124ea913e109a15.txt',
#  'b5cf54f877f2e5b8_jpg.rf.50522416f09cd8269124ea913e109a15_copy1.txt',
#  'b5cf54f877f2e5b8_jpg.rf.d15277dc5abd3e3456ebf2eccdfd0c0f.txt',
#  'b5cf54f877f2e5b8_jpg.rf.d15277dc5abd3e3456ebf2eccdfd0c0f_copy1.txt',
#  'b6024eea086419a9_jpg.rf.f4e9e37ab1ca9eebd3d56d4c7a92b40d.txt',
#  'b6024eea086419a9_jpg.rf.f4e9e37ab1ca9eebd3d56d4c7a92b40d_copy1.txt',
#  'b6ef035d775a3ee6_jpg.rf.05c24e6119eaf95ec24deba3646701cd.txt',
#  'b6ef035d775a3ee6_jpg.rf.05c24e6119eaf95ec24deba3646701cd_copy1.txt',
#  'b6ef035d775a3ee6_jpg.rf.7764b0c46d07061ffbc53f73f21555df.txt',
#  'b6ef035d775a3ee6_jpg.rf.7764b0c46d07061ffbc53f73f21555df_copy1.txt',
#  'b6ef035d775a3ee6_jpg.rf.dab61f7db02b4179a5aa1e657f0fab49.txt',
#  'b6ef035d775a3ee6_jpg.rf.dab61f7db02b4179a5aa1e657f0fab49_copy1.txt',
#  'b8091ac0e6f9e0b7_jpg.rf.9f91e08827bc1213fbee293d1cdcd22f.txt',
#  'b8091ac0e6f9e0b7_jpg.rf.9f91e08827bc1213fbee293d1cdcd22f_copy1.txt',
#  'c011f81b20441db8_jpg.rf.23a015ec96049def73e5c922c1b0d76d.txt',
#  'c011f81b20441db8_jpg.rf.23a015ec96049def73e5c922c1b0d76d_copy1.txt',
#  'c011f81b20441db8_jpg.rf.47dce78ba0d82b386966bd8f5286e545.txt',
#  'c011f81b20441db8_jpg.rf.47dce78ba0d82b386966bd8f5286e545_copy1.txt',
#  'c011f81b20441db8_jpg.rf.a6c22e68775bf0261353728e75441958.txt',
#  'c011f81b20441db8_jpg.rf.a6c22e68775bf0261353728e75441958_copy1.txt',
#  'c332dafc225470a4_jpg.rf.a7e7e0ed187f5c4bd40b2de3c4367f4f.txt',
#  'c332dafc225470a4_jpg.rf.a7e7e0ed187f5c4bd40b2de3c4367f4f_copy1.txt',
#  'c7d1b8d77ca90b86_jpg.rf.07b30ffdaffda4f111679de848b9b464.txt',
#  'c7d1b8d77ca90b86_jpg.rf.07b30ffdaffda4f111679de848b9b464_copy1.txt',
#  'c7d1b8d77ca90b86_jpg.rf.34d59ceac96b2c80178a0d25bffd5ec3.txt',
#  'c7d1b8d77ca90b86_jpg.rf.34d59ceac96b2c80178a0d25bffd5ec3_copy1.txt',
#  'c7d1b8d77ca90b86_jpg.rf.bc345dc97b1d7d4c73fe67a60a598852.txt',
#  'c7d1b8d77ca90b86_jpg.rf.bc345dc97b1d7d4c73fe67a60a598852_copy1.txt',
#  'cac550631e35c126_jpg.rf.c468ab8eff3df3ec82e28491f5ccc2ea.txt',
#  'cac550631e35c126_jpg.rf.c468ab8eff3df3ec82e28491f5ccc2ea_copy1.txt',
#  'd272dacff63fca25_jpg.rf.e1e385d7205ce15e8885420b8c66ee59.txt',
#  'd272dacff63fca25_jpg.rf.e1e385d7205ce15e8885420b8c66ee59_copy1.txt',
#  'd359cc7acdb29ca3_jpg.rf.5c46325754087f558a3da9e8783bc511.txt',
#  'd359cc7acdb29ca3_jpg.rf.5c46325754087f558a3da9e8783bc511_copy1.txt',
#  'd59cf3fa7dadc375_jpg.rf.5effab913ef413572dfa41ffe3fb67d4.txt',
#  'd59cf3fa7dadc375_jpg.rf.5effab913ef413572dfa41ffe3fb67d4_copy1.txt',
#  'd59cf3fa7dadc375_jpg.rf.a1d1a214e514faa60eacf63f4b8b61e1.txt',
#  'd59cf3fa7dadc375_jpg.rf.a1d1a214e514faa60eacf63f4b8b61e1_copy1.txt',
#  'd9b22866a65a88bd_jpg.rf.18a428a32731bafa544e2770eecc701f.txt',
#  'd9b22866a65a88bd_jpg.rf.18a428a32731bafa544e2770eecc701f_copy1.txt',
#  'd9b22866a65a88bd_jpg.rf.35f7001948d751ddf495dbbc347787ab.txt',
#  'd9b22866a65a88bd_jpg.rf.35f7001948d751ddf495dbbc347787ab_copy1.txt',
#  'd9b22866a65a88bd_jpg.rf.55beaa18bace1c9a65f04dc7a0b95471.txt',
#  'd9b22866a65a88bd_jpg.rf.55beaa18bace1c9a65f04dc7a0b95471_copy1.txt',
#  'da6361535bd21f29_jpg.rf.04a7248b4356274a67cda3a2f0ef4a72.txt',
#  'da6361535bd21f29_jpg.rf.04a7248b4356274a67cda3a2f0ef4a72_copy1.txt',
#  'da6361535bd21f29_jpg.rf.90c0c2ee8c3599fd9785cc1b3aa8ea14.txt',
#  'da6361535bd21f29_jpg.rf.90c0c2ee8c3599fd9785cc1b3aa8ea14_copy1.txt',
#  'da6361535bd21f29_jpg.rf.b7a0250082564c564019236d91abf27f.txt',
#  'da6361535bd21f29_jpg.rf.b7a0250082564c564019236d91abf27f_copy1.txt',
#  'dd2895e2455e2e06_jpg.rf.65ed52f1b064fa90a37cca17f72b40c2.txt',
#  'dd2895e2455e2e06_jpg.rf.65ed52f1b064fa90a37cca17f72b40c2_copy1.txt',
#  'dd2895e2455e2e06_jpg.rf.c99251b2f5798659825b3dc926a7ef05.txt',
#  'dd2895e2455e2e06_jpg.rf.c99251b2f5798659825b3dc926a7ef05_copy1.txt',
#  'de1c62ab565a93ac_jpg.rf.b9daf285cc0adb6ed3b96622d4ba1156.txt',
#  'de1c62ab565a93ac_jpg.rf.b9daf285cc0adb6ed3b96622d4ba1156_copy1.txt',
#  'de1c62ab565a93ac_jpg.rf.bb18818fe61003f74d9162845ca1894a.txt',
#  'de1c62ab565a93ac_jpg.rf.bb18818fe61003f74d9162845ca1894a_copy1.txt',
#  'e0feba40525b0ecf_jpg.rf.a27a9c5a1a332da803f3c7c37adc51fa.txt',
#  'e0feba40525b0ecf_jpg.rf.a27a9c5a1a332da803f3c7c37adc51fa_copy1.txt',
#  'e0feba40525b0ecf_jpg.rf.d6d9ebb43d1a475e8f91673842f6c867.txt',
#  'e0feba40525b0ecf_jpg.rf.d6d9ebb43d1a475e8f91673842f6c867_copy1.txt',
#  'e0feba40525b0ecf_jpg.rf.dca59f44150765348db8128bd77f77d5.txt',
#  'e0feba40525b0ecf_jpg.rf.dca59f44150765348db8128bd77f77d5_copy1.txt',
#  'e2328f592976bd94_jpg.rf.62294fed7d4669c0046d0718388805c7.txt',
#  'e2328f592976bd94_jpg.rf.62294fed7d4669c0046d0718388805c7_copy1.txt',
#  'e2328f592976bd94_jpg.rf.ab5c6b001e7312cfc7835c85adcadd1f.txt',
#  'e2328f592976bd94_jpg.rf.ab5c6b001e7312cfc7835c85adcadd1f_copy1.txt',
#  'e2328f592976bd94_jpg.rf.d6a6cf2ac4e97b2f8e8f556230443cfc.txt',
#  'e2328f592976bd94_jpg.rf.d6a6cf2ac4e97b2f8e8f556230443cfc_copy1.txt',
#  'e3214fceb5cc1e6e_jpg.rf.0083da0af0bf999fe1657e3407d5ec54.txt',
#  'e3214fceb5cc1e6e_jpg.rf.0083da0af0bf999fe1657e3407d5ec54_copy1.txt',
#  'e3214fceb5cc1e6e_jpg.rf.42b4d124e8f953fbd80539786d3510b9.txt',
#  'e3214fceb5cc1e6e_jpg.rf.42b4d124e8f953fbd80539786d3510b9_copy1.txt',
#  'e3214fceb5cc1e6e_jpg.rf.faff17b6db8df083693a79c898a8a1ce.txt',
#  'e3214fceb5cc1e6e_jpg.rf.faff17b6db8df083693a79c898a8a1ce_copy1.txt',
#  'e37732ab802fb4d0_jpg.rf.383d1b8f2c924a36b11f7abf20a6b1df.txt',
#  'e37732ab802fb4d0_jpg.rf.383d1b8f2c924a36b11f7abf20a6b1df_copy1.txt',
#  'e37732ab802fb4d0_jpg.rf.4a80cdb0f4870572d212711757a2aa55.txt',
#  'e37732ab802fb4d0_jpg.rf.4a80cdb0f4870572d212711757a2aa55_copy1.txt',
#  'e69b44f5e18e18a3_jpg.rf.1bb7518f751049b090b8a5766c3f056d.txt',
#  'e69b44f5e18e18a3_jpg.rf.1bb7518f751049b090b8a5766c3f056d_copy1.txt',
#  'e69b44f5e18e18a3_jpg.rf.c43514d18cf06294b88d5932282bf2c8.txt',
#  'e69b44f5e18e18a3_jpg.rf.c43514d18cf06294b88d5932282bf2c8_copy1.txt',
#  'e69b44f5e18e18a3_jpg.rf.f1c563ee194c5828a0bfe4941878346e.txt',
#  'e69b44f5e18e18a3_jpg.rf.f1c563ee194c5828a0bfe4941878346e_copy1.txt',
#  'e7597fedbd91b6a7_jpg.rf.22d57bdc7bfb18af45452d88100e98df.txt',
#  'e7597fedbd91b6a7_jpg.rf.22d57bdc7bfb18af45452d88100e98df_copy1.txt',
#  'e7597fedbd91b6a7_jpg.rf.ff77b54cc3118fd4bd4472f7fe3ac705.txt',
#  'e7597fedbd91b6a7_jpg.rf.ff77b54cc3118fd4bd4472f7fe3ac705_copy1.txt',
#  'eabd252fed81fbed_jpg.rf.0aa9aa975f8d4338c8f6ae47abfde75a.txt',
#  'eabd252fed81fbed_jpg.rf.0aa9aa975f8d4338c8f6ae47abfde75a_copy1.txt',
#  'eabd252fed81fbed_jpg.rf.4979cd56a043a3cd25c5ff907bbb1951.txt',
#  'eabd252fed81fbed_jpg.rf.4979cd56a043a3cd25c5ff907bbb1951_copy1.txt',
#  'eabd252fed81fbed_jpg.rf.4c267285d5750cc42ee096a943ee29bf.txt',
#  'eabd252fed81fbed_jpg.rf.4c267285d5750cc42ee096a943ee29bf_copy1.txt',
#  'eccec93d96324e27_jpg.rf.224505d660ceaea4955416b34edc3061.txt',
#  'eccec93d96324e27_jpg.rf.224505d660ceaea4955416b34edc3061_copy1.txt',
#  'eccec93d96324e27_jpg.rf.262c74203ee0a74c7a57d8a4f923b518.txt',
#  'eccec93d96324e27_jpg.rf.262c74203ee0a74c7a57d8a4f923b518_copy1.txt',
#  'eccec93d96324e27_jpg.rf.b0cd95f32d65136fc4aa9fb24d2090db.txt',
#  'eccec93d96324e27_jpg.rf.b0cd95f32d65136fc4aa9fb24d2090db_copy1.txt',
#  'edad141f1c0c480e_jpg.rf.063c3ca91b6ae102a260e1e8e68be289.txt',
#  'edad141f1c0c480e_jpg.rf.063c3ca91b6ae102a260e1e8e68be289_copy1.txt',
#  'edad141f1c0c480e_jpg.rf.43fb7439fffe21ccdae34eadc3e26401.txt',
#  'edad141f1c0c480e_jpg.rf.43fb7439fffe21ccdae34eadc3e26401_copy1.txt',
#  'f045d1819e2d038d_jpg.rf.37f1af50df349f46bb268977dfb73b76.txt',
#  'f045d1819e2d038d_jpg.rf.37f1af50df349f46bb268977dfb73b76_copy1.txt',
#  'f045d1819e2d038d_jpg.rf.a41d75df89689387f45a797159632d58.txt',
#  'f045d1819e2d038d_jpg.rf.a41d75df89689387f45a797159632d58_copy1.txt',
#  'f045d1819e2d038d_jpg.rf.f114f64843e4bfc056ebe5d4569bfaab.txt',
#  'f045d1819e2d038d_jpg.rf.f114f64843e4bfc056ebe5d4569bfaab_copy1.txt',
#  'f0b6ea3487c300ba_jpg.rf.0892efa330a8ce2743be204b12dc8162.txt',
#  'f0b6ea3487c300ba_jpg.rf.0892efa330a8ce2743be204b12dc8162_copy1.txt',
#  'f0b6ea3487c300ba_jpg.rf.cfbfb7187a088189cf2a7c648009b39f.txt',
#  'f0b6ea3487c300ba_jpg.rf.cfbfb7187a088189cf2a7c648009b39f_copy1.txt',
#  'feb0236c0b6281a9_jpg.rf.82836a6f62f2e3f47f566c3c7440f640.txt',
#  'feb0236c0b6281a9_jpg.rf.82836a6f62f2e3f47f566c3c7440f640_copy1.txt',
#  'feb0236c0b6281a9_jpg.rf.86361e0da1b2203a7d3651b75d04f6b5.txt',
#  'feb0236c0b6281a9_jpg.rf.86361e0da1b2203a7d3651b75d04f6b5_copy1.txt',
#  'feb0236c0b6281a9_jpg.rf.b94d61db901984dcb9baa097c67a1e05.txt',
#  'feb0236c0b6281a9_jpg.rf.b94d61db901984dcb9baa097c67a1e05_copy1.txt',
#  'ff2ae958e4c189e0_jpg.rf.965dab2e789072ce3ed3e6d15b9c338a.txt',
#  'ff2ae958e4c189e0_jpg.rf.965dab2e789072ce3ed3e6d15b9c338a_copy1.txt']

# %%
images_b = [f for f in os.listdir('temp_b/images') if f.endswith('.jpg')]
for img in images_b:
    shutil.copy(f'temp_b/images/{img}', f'yolo_dataset/new_train/images/{img}')
    shutil.copy(f'temp_b/labels/{img.replace(".jpg", ".txt")}', f'yolo_dataset/new_train/labels/{img.replace(".jpg", ".txt")}')

images_p = [f for f in os.listdir('temp_p/images') if f.endswith('.jpg')]
for img in images_p:
    shutil.copy(f'temp_p/images/{img}', f'yolo_dataset/new_train/images/{img}')
    shutil.copy(f'temp_p/labels/{img.replace(".jpg", ".txt")}', f'yolo_dataset/new_train/labels/{img.replace(".jpg", ".txt")}')
    
images_w = [f for f in os.listdir('temp_w/images') if f.endswith('.jpg')]
for img in images_w:
    shutil.copy(f'temp_w/images/{img}', f'yolo_dataset/new_train/images/{img}')
    shutil.copy(f'temp_w/labels/{img.replace(".jpg", ".txt")}', f'yolo_dataset/new_train/labels/{img.replace(".jpg", ".txt")}')
    
images_mix = [f for f in os.listdir('temp_mix/images') if f.endswith('.jpg')]
for img in images_mix:
    shutil.copy(f'temp_mix/images/{img}', f'yolo_dataset/new_train/images/{img}')
    shutil.copy(f'temp_mix/labels/{img.replace(".jpg", ".txt")}', f'yolo_dataset/new_train/labels/{img.replace(".jpg", ".txt")}')

# %%
# def duplicate_specific_amount(train_class_banana, labels_dir, images_dir, dest_labels_dir, dest_images_dir, 
#                             current_count=955, target_count=1350):
#     """
#     Duplicate random images from train_class_banana to reach target_count
    
#     Args:
#         train_class_banana: List of label file names (.txt) containing banana class
#         labels_dir: Source labels directory
#         images_dir: Source images directory  
#         dest_labels_dir: Destination labels directory
#         dest_images_dir: Destination images directory
#         current_count: Current number of banana images (955)
#         target_count: Target number of banana images (1350)
#         seed: Random seed for reproducibility
#     """
#     # Set random seed for reproducibility
#     random.seed(42)
    
#     # Create destination directories
#     os.makedirs(dest_labels_dir, exist_ok=True)
#     os.makedirs(dest_images_dir, exist_ok=True)
    
#     # Calculate how many images we need to duplicate
#     needed_duplicates = target_count - current_count
#     print(f"Current: {current_count}, Target: {target_count}")
#     print(f"Need to duplicate: {needed_duplicates} images")
    
#     # First, copy all original files
#     train_files = []
#     valid_files = []
    
#     for label_file in train_class_banana:
#         if not label_file.endswith('.txt'):
#             continue
            
#         label_src_path = os.path.join(labels_dir, label_file)
#         image_file = label_file.replace('.txt', '.jpg')
#         image_src_path = os.path.join(images_dir, image_file)
        
#         # Check if both files exist
#         if os.path.exists(label_src_path) and os.path.exists(image_src_path):
#             # Copy original files
#             label_dest_path = os.path.join(dest_labels_dir, label_file)
#             image_dest_path = os.path.join(dest_images_dir, image_file)
            
#             shutil.copy(label_src_path, label_dest_path)
#             shutil.copy(image_src_path, image_dest_path)
            
#             train_files.append(label_file)
#             valid_files.append(label_file)
#         else:
#             print(f"WARNING: Missing files for {label_file}")
    
#     # Now randomly select files to duplicate
#     if needed_duplicates > 0 and valid_files:
#         # Create list of files to duplicate (can repeat if needed)
#         files_to_duplicate = []
        
#         # If we need more duplicates than available files, we'll duplicate some files multiple times
#         while len(files_to_duplicate) < needed_duplicates:
#             remaining = needed_duplicates - len(files_to_duplicate)
#             if remaining >= len(valid_files):
#                 # Add all files
#                 files_to_duplicate.extend(valid_files)
#             else:
#                 # Add random sample of remaining files
#                 files_to_duplicate.extend(random.sample(valid_files, remaining))
        
#         # Shuffle the list for random order
#         random.shuffle(files_to_duplicate)
        
#         # Keep track of how many times each file has been duplicated
#         duplicate_count = {}
        
#         # Create duplicates
#         for i, label_file in enumerate(files_to_duplicate):
#             # Count duplicates for this file
#             if label_file not in duplicate_count:
#                 duplicate_count[label_file] = 0
#             duplicate_count[label_file] += 1
            
#             # Create new filenames
#             copy_suffix = f"_dup{duplicate_count[label_file]}"
#             new_label_file = label_file.replace('.txt', f'{copy_suffix}.txt')
#             new_image_file = label_file.replace('.txt', f'{copy_suffix}.jpg')
            
#             # Source paths
#             label_src_path = os.path.join(labels_dir, label_file)
#             image_src_path = os.path.join(images_dir, label_file.replace('.txt', '.jpg'))
            
#             # Destination paths
#             new_label_dest_path = os.path.join(dest_labels_dir, new_label_file)
#             new_image_dest_path = os.path.join(dest_images_dir, new_image_file)
            
#             # Copy files
#             shutil.copy(label_src_path, new_label_dest_path)
#             shutil.copy(image_src_path, new_image_dest_path)
            
#             train_files.append(new_label_file)
            
#             if (i + 1) % 50 == 0:
#                 print(f"Duplicated {i + 1}/{needed_duplicates} files...")
                
#     return train_files

# %%
# test_labels_dir = 'temp_b\labels'
# test_images_dir = 'temp_b\images'
# train_files = duplicate_specific_amount(train_class_banana, labels_dir, images_dir, test_labels_dir, test_images_dir, current_count=955, target_count=1350)
# Out:
# Current: 955, Target: 1350
# Need to duplicate: 395 images
# Duplicated 50/395 files...
# Duplicated 100/395 files...
# Duplicated 150/395 files...
# Duplicated 200/395 files...
# Duplicated 250/395 files...
# Duplicated 300/395 files...
# Duplicated 350/395 files...
